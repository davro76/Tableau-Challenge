# %%
# Import required libraries
import pandas as pd
import os
import csv
from datetime import datetime, timedelta

# %%
# From the operating system get the current working direcotry
os.getcwd()
# Out:
# '/Users/rodneydavermann/Desktop/Tableau-Challenge'

# %%
# Display the file names inside the working directory
files = os.listdir()
files
# Out:
# ['.DS_Store',
#  'README.md',
#  '.ipynb_checkpoints',
#  '.git',
#  'Data',
#  'citybike.ipynb']

# %%
# Read csv bike data files 
bike_data_202101 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202101-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202012 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202012-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202011 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202011-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202010 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202010-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202009 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202009-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202008 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202008-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202007 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202007-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202006 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202006-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202005 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202005-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202004 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202004-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202003 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202003-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202002 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202002-citibike-tripdata.csv", error_bad_lines=False)
bike_data_202001 = pd.read_csv("/Users/rodneydavermann/Desktop/Tableau-Challenge/Data/JC-202001-citibike-tripdata.csv", error_bad_lines=False)

# %%
bike_data_202001
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# ...
